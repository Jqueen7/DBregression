# %%
import pandas as pd
import numpy as np

# %%
infotable = pd.read_csv('./2022q4_form13f/INFOTABLE.tsv',sep='\t')
# Out:
# /var/folders/h2/xtv6rzm1081cpt_clcdbqmt00000gn/T/ipykernel_75195/2349675760.py:1: DtypeWarning: Columns (8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   infotable = pd.read_csv('./2022q4_form13f/INFOTABLE.tsv',sep='\t')

# %%
infotable[infotable['NAMEOFISSUER'] == 'BERKSHIRE HATHAWAY INC DEL CL B NEW']
# Out:
#              ACCESSION_NUMBER  INFOTABLE_SK  \
# 18       0001954551-22-000008      74878548
# 190      0001954551-22-000007      74883717
# 278      0001954551-22-000006      74878669
# 456      0001954551-22-000005      74885304
# 484      0001954551-22-000004      74880773
# ...                       ...           ...
# 2542316  0001799284-22-000004      72327519
# 2549114  0001409362-22-000005      72321541
# 2551162  0001943228-22-000002      72339570
# 2552601  0001057395-22-000004      72340760
# 2556314  0001561790-22-000012      72339203
#
#                                 NAMEOFISSUER  TITLEOFCLASS      CUSIP  VALUE  \
# 18       BERKSHIRE HATHAWAY INC DEL CL B NEW         Stock  084670702    613
# 190      BERKSHIRE HATHAWAY INC DEL CL B NEW         Stock  084670702    574
# 278      BERKSHIRE HATHAWAY INC DEL CL B NEW         Stock  084670702   1649
# 456      BERKSHIRE HATHAWAY INC DEL CL B NEW         Stock  084670702   1675
# ...

# %%
coverpage = pd.read_csv('./2022q4_form13f/COVERPAGE.tsv',sep='\t')

# %%
coverpage
# Out:
#           ACCESSION_NUMBER REPORTCALENDARORQUARTER ISAMENDMENT  AMENDMENTNO  \
# 0     0001954551-22-000008             31-DEC-2021         NaN          NaN
# 1     0001954551-22-000007             30-SEP-2021         NaN          NaN
# 2     0001954551-22-000006             30-JUN-2021         NaN          NaN
# 3     0001954551-22-000005             31-MAR-2022         NaN          NaN
# 4     0001954551-22-000004             30-JUN-2022         NaN          NaN
# ...                    ...                     ...         ...          ...
# 9005  0001297731-22-000007             30-SEP-2022           Y          5.0
# 9006  0001297731-22-000006             30-SEP-2022         NaN          NaN
# 9007  0001297731-22-000005             30-SEP-2022         NaN          NaN
# 9008  0001547676-22-000012             30-SEP-2022         NaN          NaN
# 9009  0001062993-22-020107             30-JUN-2022         NaN          NaN
#
# ...

# %%
SUBMISSION = pd.read_csv('./2022q4_form13f/SUBMISSION.tsv',sep='\t')

# %%
SUBMISSION
# Out:
#           ACCESSION_NUMBER  FILING_DATE SUBMISSIONTYPE      CIK PERIODOFREPORT
# 0     0001214659-22-012820  31-OCT-2022         13F-HR  1744091    30-SEP-2022
# 1     0001085146-22-003673  31-OCT-2022         13F-HR   801051    30-SEP-2022
# 2     0001912128-22-000005  31-OCT-2022         13F-HR  1912128    30-SEP-2022
# 3     0001172661-22-002265  31-OCT-2022         13F-HR  1887163    30-SEP-2022
# 4     0001945037-22-000002  31-OCT-2022         13F-HR  1945037    30-SEP-2022
# ...                    ...          ...            ...      ...            ...
# 9005  0001567619-22-021090  01-DEC-2022       13F-HR/A  1055964    31-MAR-2018
# 9006  0001085146-22-004224  01-DEC-2022       13F-HR/A  1418773    30-JUN-2021
# 9007  0001567619-22-021097  01-DEC-2022       13F-HR/A  1055964    31-DEC-2018
# 9008  0001085146-22-004226  01-DEC-2022       13F-HR/A  1418773    31-DEC-2021
# 9009  0001085146-22-004212  01-DEC-2022       13F-HR/A  1011659    30-JUN-2020
#
# [9010 rows x 5 columns]

# %%
OTHERMANAGER = pd.read_csv('./2022q4_form13f/OTHERMANAGER.tsv',sep='\t')

# %%
OTHERMANAGER
# Out:
#           ACCESSION_NUMBER  OTHERMANAGER_SK        CIK FORM13FFILENUMBER  \
# 0     0001390777-22-000118           142163   937729.0         028-10991
# 1     0001390777-22-000118           142162  1725296.0         028-18741
# 2     0001390777-22-000118           142164  1465109.0         028-13573
# 3     0001357643-22-000007           142141  1357550.0               NaN
# 4     0001357643-22-000006           142140  1357550.0               NaN
# ...                    ...              ...        ...               ...
# 3910  0001905128-22-000005           138223        NaN         028-16230
# 3911  0000796370-22-000008           138234   916542.0         028-05990
# 3912  0001911876-22-000041           138215  1911876.0               NaN
# 3913  0001911876-22-000040           138217  1911876.0               NaN
# 3914  0001547676-22-000012           138235        NaN               NaN
#
#                                         NAME
# 0                         FAYEZ SAROFIM & CO
# ...
