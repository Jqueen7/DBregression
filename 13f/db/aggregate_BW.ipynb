# %%
import pandas as pd
import numpy as np
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()
from datetime import timedelta
import warnings
warnings.filterwarnings('ignore')
stocks_use = ['MSFT', 'VZ', 'IBM', 'JNJ', 'CSCO', 'AAPL', 'ORCL', 'INTC', 'GILD', 'VTR', 'LVS', 'CAG', 'QCOM', 'EOG', 'OXY', 'RTX', 'COP', 'FCX', 'XOM', 'CVX', 'K', 'WELL', 'ED', 'MU', 'HON', 'NEM', 'APA', 'WYNN', 'PHM', 'JNPR', 'EMR', 'BA', 'MGM', 'MO', 'BKNG', 'URI', 'CCL', 'CHRW', 'TXN', 'NTAP', 'KR', 'VRSN', 'ICE', 'MAR', 'PEP', 'INTU', 'NVDA', 'UNH', 'MCK', 'MDT', 'WY', 'CI', 'MHK', 'HES', 'TMO', 'GOOGL', 'DVN', 'PXD', 'ADBE', 'BAX', 'MRO', 'DHR', 'DGX', 'DVA', 'KLAC', 'MCHP', 'LRCX', 'MET', 'NOC', 'FFIV', 'AMAT', 'PH', 'META', 'WM', 'PFE', 'LMT', 'CAH', 'IP', 'PRU', 'AIG', 'DOV', 'MSI', 'EQT', 'CTRA', 'GE', 'AFL', 'ITW', 'VLO', 'WHR', 'GWW', 'CRM', 'ACN', 'AZO', 'JBHT', 'ABC', 'ATVI', 'LLY', 'ANSS', 'EL', 'MAS', 'CB', 'ETN', 'GS', 'TRV', 'LUV', 'GLW', 'NUE', 'HD', 'CMI', 'ISRG', 'STLD', 'DUK', 'KMX', 'TEL', 'DOW', 'PEG', 'EBAY', 'RHI', 'PKG', 'PPG', 'LNC', 'EMN', 'FISV', 'UAL', 'SYK', 'ZION', 'NDAQ', 'LOW', 'LH', 'MTD', 'O', 'EQIX', 'SBAC', 'ROK', 'T', 'TROW', 'MMC', 'ABT', 'ALL', 'AME', 'HIG', 'LUMN', 'AKAM', 'WAB', 'GIS', 'AMZN', 'BLK', 'ADP', 'CDNS', 'BSX', 'MS', 'AEP', 'SBNY', 'PGR', 'BEN', 'UHS', 'PAYX', 'ON', 'CLX', 'BDX', 'NVR', 'SCHW', 'SLB', 'HAL', 'STT', 'IDXX', 'AMP', 'EFX', 'RL', 'BMY', 'MSCI', 'AAP', 'KO', 'SYY', 'EA', 'ORLY', 'SHW', 'TGT', 'TSN', 'PSX', 'BIIB', 'SPGI', 'MOS', 'WMT', 'SO', 'UNP', 'ETR', 'WDC', 'CCI', 'CMG', 'CTSH', 'PCAR', 'NEE', 'AXP', 'ILMN', 'GD', 'ADI', 'ELV', 'MMM', 'HST', 'ROST', 'HUM', 'FMC', 'JCI', 'COST', 'PCG', 'ADM', 'PLD', 'PSA', 'HSY', 'AMT', 'MDLZ', 'RCL', 'CF', 'SPG', 'TAP', 'PM', 'AMGN', 'LHX', 'LKQ', 'TRMB', 'CTAS', 'CNP', 'CSX', 'RSG', 'RE', 'TECH', 'IFF', 'CRL', 'FDS', 'JKHY', 'FITB', 'ALK', 'RF', 'APH', 'SNA', 'BAC', 'NWL', 'CE', 'EIX', 'LYB', 'VRSK', 'MLM', 'FLT', 'SWKS', 'AVY', 'DIS', 'SBUX', 'MCD', 'DISH', 'MRK', 'YUM', 'DRI', 'DHI', 'TXT', 'NRG', 'D', 'FDX', 'KDP', 'STZ', 'FE', 'BWA', 'RMD', 'UPS', 'WBA', 'HOLX', 'EXC', 'EW', 'DE', 'CPB', 'BXP', 'DAL', 'MNST', 'PFG', 'REGN', 'IPG', 'CVS', 'LEN', 'TJX', 'COF', 'SWK', 'F', 'SJM', 'CBRE', 'AIZ', 'HBAN', 'USB', 'SEE', 'VMC', 'TFC', 'MCO', 'FIS', 'CMA', 'L', 'APD', 'CME', 'MKC', 'JPM', 'HRL', 'IVZ', 'DFS', 'ROP', 'TPR', 'PWR', 'KMB', 'PG', 'PPL', 'CMCSA', 'CAT', 'WFC', 'XRAY', 'V', 'J', 'COO', 'C', 'RJF', 'MPC', 'WAT', 'IT', 'FTNT', 'SNPS', 'ECL', 'ARE', 'GPN', 'IRM', 'KEY', 'WTW', 'PKI', 'BALL', 'PNC', 'GL', 'FRT', 'NWSA', 'MTB', 'WRK', 'ALGN', 'HSIC', 'EXR', 'BIO', 'TSCO', 'ALLE', 'AJG', 'UDR', 'IEX', 'CPT', 'DLR', 'REG', 'KIM', 'NDSN', 'ESS', 'AEE', 'LNT', 'AWK', 'WEC', 'DTE', 'AES', 'PNW', 'ES', 'XEL', 'ATO', 'CMS', 'ALB', 'CHD', 'TSLA', 'EXPD', 'NOW', 'ROL', 'CPRT', 'CINF', 'WRB', 'TMUS', 'VFC', 'VRTX', 'EXPE', 'NTRS', 'PTC', 'DPZ', 'CL', 'APTV', 'ODFL', 'GPC', 'DG', 'DD', 'HCA', 'KHC', 'AOS', 'EQR', 'AVB', 'SRE', 'GM', 'DLTR', 'PEAK', 'POOL', 'ZBH', 'ACGL', 'CDW', 'OMC', 'HLT', 'LW', 'FAST', 'LDOS', 'ANET', 'EVRG', 'NSC', 'NI', 'ADSK', 'FTV', 'FANG', 'TT', 'AON', 'BK', 'WST', 'CARR', 'DXCM', 'STE', 'FRC', 'TFX', 'SIVB', 'MKTX', 'CFG', 'BRO', 'FOXA', 'KMI', 'INVH', 'MAA', 'BKR', 'VTRS', 'CBOE', 'BBY', 'HII', 'PAYC', 'CSGP', 'CDAY', 'PYPL', 'MA', 'LIN', 'A', 'CTVA', 'HPQ', 'KEYS', 'AMD', 'ZBRA', 'ABBV', 'AVGO', 'HPE', 'XYL', 'MRNA', 'GRMN', 'FSLR', 'IR', 'TER', 'MPWR', 'BR', 'INCY', 'QRVO', 'OKE', 'IQV', 'GEN', 'PNR', 'SEDG', 'TTWO', 'CTLT', 'TDG', 'EPAM', 'CNC', 'LYV', 'NFLX', 'TDY', 'MOH', 'TYL', 'HWM', 'ETSY', 'HAS', 'ZTS', 'NKE', 'CHTR', 'ULTA', 'OTIS', 'NXPI', 'WBD', 'DXC', 'STX', 'BBWI', 'TRGP', 'VICI', 'AAL', 'NCLH', 'PARA', 'GNRC', 'ENPH']

# %%
institution = 'Bridgewater Associates, LP'
y = '2013'
q = 'Q4'
df = pd.read_csv(f'./people/{institution}/{institution} {q} {y} 13F Top Portfolio Holdings.csv')
df.head()
# Out:
#    Sym                   Issuer Name                Cl      CUSIP  \
# 0  VWO  VANGUARD INTL EQUITY INDEX F  FTSE EMR MKT ETF  922042858
# 1  SPY           SPDR S&P 500 ETF TR           TR UNIT  78462F103
# 2  EEM                       ISHARES  MSCI EMG MKT ETF  464287234
# 3  LQD                       ISHARES  IBOXX INV CP ETF  464287242
# 4  IVV                       ISHARES   CORE S&P500 ETF  464287200
#
#   Value ($000)     %       Shares  Principal  Option Type
# 0    4,200,302   34%  102,097,760        NaN          NaN
# 1    3,543,610   28%   19,186,800        NaN          NaN
# 2    3,235,870   26%   77,422,430        NaN          NaN
# 3       43,089  0.3%      377,355        NaN          NaN
# 4       32,489  0.3%      175,000        NaN          NaN

# %%
df_merged = pd.DataFrame(columns=['Sym', 'Amount'])

# %%
df_merged
# Out:
# Empty DataFrame
# Columns: [Sym, Amount]
# Index: []

# %%
institution = 'Bridgewater Associates, LP'
quarters = ['Q1','Q2','Q3','Q4']
error_price = []

years = [str(y) for y in range(2013,2023)]
for y in years:
    for q in quarters:
        try:
            df = pd.read_csv(f'./people/{institution}/{institution} {q} {y} 13F Top Portfolio Holdings.csv')
            for i in range(len(df)):
                df['Value ($000)'][i]=df['Value ($000)'].values[i].replace(',','')
            df['Value ($000)'] = df['Value ($000)'].astype(float)
            df = df.drop(['Cl','CUSIP','%','Principal','Option Type','Issuer Name','Shares'], axis=1)
        
            quarter_dict = {'Q1':'03-31','Q2':'06-30','Q3':'09-30','Q4':'12-31'}
            day = y+'-'+quarter_dict[q]
            dday = pd.to_datetime(day)
            # NumShares = []
            for i in range(len(df)):
                try:
                    ticker = df['Sym'][i]
                    if ticker in error_price:
                        continue
                    prices = pdr.get_data_yahoo(ticker,start=day, end = dday + timedelta(5))['Close']
                    try:
                        price = prices.loc[y+'-'+quarter_dict[q]]
                    except:
                        price = prices.iloc[0]
                    df['Value ($000)'][i] = round(df['Value ($000)'][i]/price,1)
                    #NumShares.append(np.round(amt,1))
                    
                except:
                    print('shat')
                    if ticker not in error_price:
                        error_price.append(ticker)
                    pass
                
            df.rename(columns={'Value ($000)':'Amount (000)'}, inplace=True)
            
            for i in range(len(df)):
                if df['Sym'][i] not in stocks_use:
                    df.drop(i, axis=0,inplace=True)
            df.reset_index(inplace=True)
            del df['index']
            
            cnt = len(df)
            for s in stocks_use:
                if s not in list(df['Sym']):
                    df.loc[cnt] = [s, 0] 
                    #cnt += 1
            #if len(df) != 90:
                #print(f'Error for {y} {q}')
                #break;
            
            quarter_dict2 = {'Q1':'03-01','Q2':'06-01','Q3':'09-01','Q4':'12-01'}
            df['date'] = pd.to_datetime(f'{y}-{quarter_dict2[q]}')
            df = df.set_index('date')
            
            df_merged = pd.concat([df_merged,df],axis=0)
            print(f'Merged {y} {q}!')
        except:
            print(f'Error with Loading Data {y} {q}..')
            pass
# Out:
# Error with Loading Data 2013 Q1..
# Error with Loading Data 2013 Q2..
# Error with Loading Data 2013 Q3..
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# shat
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
print(error_price)
# Out:
# [nan, 'BRCM', 'GG', 'MXIM', 'HWP', 'APC', 'FRX', 'CHK', 'NLOK', 'SNDK', 'XLNX', 'HOT', 'RHT', 'TIF', 'HFC', 'AGN', 'NBL', 'DNR', 'TLM', 'PTR', 'SPLS', 'WFM', 'VAR', 'CERN', 'LO', 'BCR', 'CXO', 'MJN', 'CREE', 'CELG', 'CVC', 'PMCS', 'CFX', 'BKS', 'BTU', 'BEAM', 'WLTW', 'BGC', 'ACAS', 'ENDP', 'BRCD', 'WOOF', 'LM', 'ROC', 'GRA', 'CYT', 'INFA', 'SWI', 'BEAV', 'LXK', 'UFS', 'TWC', 'MCRS', 'NUAN', 'URS', 'TWTC', 'TIBX', 'DOW', 'BHI', 'LNKD', 'TOC', 'SDRLF', 'PCP', 'ALXN', 'MON', 'N', 'ALTR', 'WLL', 'CNQR', 'RTN', 'LLTC', 'RAX', 'VALPQ', 'RKT', 'ANTM', 'CAM', 'PNRA', 'CAB', 'VIAC', 'CFN', 'KSU', 'DNKN', 'PCL', 'TRW', 'AVP', 'XL', 'TSS', 'JAH', 'POT', 'JOY', 'DISCA', 'AGU', 'PX', 'AXLL', 'VIAB', 'LB', 'STJ', 'MYL', 'RDC', 'DISCK', 'TW', 'CIT', 'KRFT', 'ADT', 'CVD', 'LPT', 'FSL', 'OCR', 'PBCT', 'LVLT', 'SPNX', 'MSGN', 'WDR', 'AOL', 'PRE', 'LLL', 'DNY', 'QLGC', 'QEP', 'SE', 'MDP', 'STI', 'VAL', 'AVX', 'OAS', 'PLCM', 'ARG', 'IHS', 'GWR', 'FCS', 'DNB', 'ISIL', 'CY', 'AMTD', 'TCO', 'TFCFA', 'ATG',
# ...

# %%
for s in stocks_use:
    if s in error_price:
        stocks_use.remove(s)
print(stocks_use)
# Out:
# ['MSFT', 'VZ', 'IBM', 'JNJ', 'CSCO', 'AAPL', 'ORCL', 'INTC', 'GILD', 'VTR', 'LVS', 'CAG', 'QCOM', 'EOG', 'OXY', 'RTX', 'COP', 'FCX', 'XOM', 'CVX', 'K', 'WELL', 'ED', 'MU', 'HON', 'NEM', 'APA', 'WYNN', 'PHM', 'JNPR', 'EMR', 'BA', 'MGM', 'MO', 'BKNG', 'URI', 'CCL', 'CHRW', 'TXN', 'NTAP', 'KR', 'VRSN', 'ICE', 'MAR', 'PEP', 'INTU', 'NVDA', 'UNH', 'MCK', 'MDT', 'WY', 'CI', 'MHK', 'HES', 'TMO', 'GOOGL', 'DVN', 'PXD', 'ADBE', 'BAX', 'MRO', 'DHR', 'DGX', 'DVA', 'KLAC', 'MCHP', 'LRCX', 'MET', 'NOC', 'FFIV', 'AMAT', 'PH', 'META', 'WM', 'PFE', 'LMT', 'CAH', 'IP', 'PRU', 'AIG', 'DOV', 'MSI', 'EQT', 'CTRA', 'GE', 'AFL', 'ITW', 'VLO', 'WHR', 'GWW', 'CRM', 'ACN', 'AZO', 'JBHT', 'ABC', 'ATVI', 'LLY', 'ANSS', 'EL', 'MAS', 'CB', 'ETN', 'GS', 'TRV', 'LUV', 'GLW', 'NUE', 'HD', 'CMI', 'ISRG', 'STLD', 'DUK', 'KMX', 'TEL', 'PEG', 'EBAY', 'RHI', 'PKG', 'PPG', 'LNC', 'EMN', 'FISV', 'UAL', 'SYK', 'ZION', 'NDAQ', 'LOW', 'LH', 'MTD', 'O', 'EQIX', 'SBAC', 'ROK', 'T', 'TROW', 'MMC', 'ABT', 'ALL', 'AME', 'HIG', 'L
# ...

# %%
for i in error_price:
    df_merged = df_merged[df_merged['Sym'] != i]
    print(f'Dropped {i} and length {len(df_merged)}')
# Out:
# Dropped nan and length 7495
# Dropped BRCM and length 7495
# Dropped GG and length 7495
# Dropped MXIM and length 7495
# Dropped HWP and length 7495
# Dropped APC and length 7495
# Dropped FRX and length 7495
# Dropped CHK and length 7495
# Dropped NLOK and length 7495
# Dropped SNDK and length 7495
# Dropped XLNX and length 7495
# Dropped HOT and length 7495
# Dropped RHT and length 7495
# Dropped TIF and length 7495
# Dropped HFC and length 7495
# Dropped AGN and length 7495
# Dropped NBL and length 7495
# Dropped DNR and length 7495
# Dropped TLM and length 7495
# Dropped PTR and length 7495
# Dropped SPLS and length 7495
# Dropped WFM and length 7495
# Dropped VAR and length 7495
# Dropped CERN and length 7495
# Dropped LO and length 7495
# Dropped BCR and length 7495
# Dropped CXO and length 7495
# Dropped MJN and length 7495
# Dropped CREE and length 7495
# Dropped CELG and length 7495
# Dropped CVC and length 7495
# Dropped PMCS and length 7495
# Dropped CFX and length 7495
# ...

# %%
sum(df_merged['Amount (000)'].isna())
# Out:
# 0

# %%
del df_merged['Amount']

# %%
df_merged.to_csv('NumShares_RayDalio.csv')

# %%
df_merged.groupby('Sym').mean()
# Out:
#       Amount (000)
# Sym
# AAL   7.589911e+04
# AAPL  7.489535e+05
# ABBV  2.989600e+03
# ALLY  1.915817e+03
# AMZN  4.413669e+03
# ...            ...
# VRSN  3.984342e+04
# VZ    2.785644e+04
# WFC   1.055213e+06
# WMT   2.037333e+04
# XOM   4.569956e+03
#
# [90 rows x 1 columns]

# %%
df_merged
# Out:
#               Sym  Amount (000)
# 2013-12-01    WFC      463458.1
# 2013-12-01     KO      400000.0
# 2013-12-01    AXP      151610.7
# 2013-12-01    IBM       71255.6
# 2013-12-01     PG       52793.1
# ...           ...           ...
# 2022-09-01  FWONA           0.0
# 2022-09-01    OGN           0.0
# 2022-09-01      T           0.0
# 2022-09-01   ORCL           0.0
# 2022-09-01    PFE           0.0
#
# [3240 rows x 2 columns]

# %%
pdr.get_data_yahoo('MSFT',start=pd.to_datetime('2016-12-31')-timedelta(1), end = pd.to_datetime('2016-12-31') + timedelta(4))['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2016-12-30 00:00:00-05:00    62.139999
# 2017-01-03 00:00:00-05:00    62.580002
# Name: Close, dtype: float64
