# %%
import pandas as pd
import numpy as np
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()
from datetime import timedelta
stocks_use = ['VWO', 'SPY', 'EEM', 'LQD', 'MSFT', 'IVV', 'VZ', 'IBM', 'JNJ', 'NLOK', 'CSCO', 'AAPL', 'ORCL', 'INTC', 'GILD', 'VTR', 'LVS', 'CAG', 'SU.TO', 'QCOM', 'EOG', 'OXY', 'PBR', 'CNQ.TO', 'RTX', 'GG', 'ABX.TO', 'BP', 'COP', 'FCX', 'XOM', 'RIO', 'IMO.TO', 'VALE', 'BRK-B', 'BHP', 'CVX', 'SCCO', 'K', 'WELL', 'ED', 'MU', 'CELG', 'CHK', 'PRGO', 'HON', 'APC', 'WU', 'NEM', 'APA', 'WYNN', 'PHM', 'JNPR', 'EMR', 'BRCM', 'WFM', 'BA', 'MGM', 'MO', 'BKNG', 'PCP', 'URI', 'CCL', 'CHRW', 'ALXN', 'WPM', 'ESRX', 'TXN', 'NTAP', 'KR', 'MON', 'CVE.TO', 'VRSN', 'ICE', 'RAD', 'MAR', 'PEP', 'EMC', 'INTU', 'YRI.TO', 'BCR', 'SPLS', 'ANDV', 'NVDA', 'AU', 'UNH', 'MCK', 'FNV.TO', 'HP', 'MDT', 'WY', 'CI', 'MHK', 'HES', 'AEM', 'TMO', 'GOOGL', 'OVV', 'DVN', 'SNDK', 'PXD', 'ADBE', 'ENB.TO', 'MXIM', 'NBL', 'BAX', 'NOV', 'MRO', 'DHR', 'DGX', 'DVA', 'KLAC', 'BFH', 'MCHP', 'LRCX', 'HOT', 'MET', 'NOC', 'RHT', 'FFIV', 'AMAT', 'N', 'PTR', 'PH', 'TRP', 'ALTR', 'META', 'WLL', 'K.TO', 'CNQR', 'VMW', 'TECK-B.TO', 'WM', 'XRX', 'PFE', 'LMT', 'COV', 'CAH', 'RTN', 'IP', 'PRU', 'AIG', 'DOV', 'RGLD', 'BMRN', 'LLTC', 'EGO', 'PTEN', 'MSI', 'SWN', 'RAX', 'TRIP', 'EQT', 'VALPQ', 'CTRA', 'GE', 'AFL', 'CPG.TO', 'ITW', 'LNKD', 'VAR', 'RRC', 'VLO', 'CERN', 'WHR', 'FBIN', 'AET', 'GWW', 'AGN', 'GFI', 'CREE', 'MUR', 'CRM', 'TKR', 'NGD.TO', 'ACN', 'AZO', 'JBHT', 'ABC', 'IGT', 'TLM', 'ATVI', 'SPXC', 'LLY', 'ANSS', 'EL', 'INFA', 'MAS', 'CXO', 'CB', 'KBR', 'ETN', 'XLNX', 'CCO.TO', 'RKT', 'GS', 'CNX', 'DNR', 'TRV', 'ANTM', 'NFG', 'LUV', 'GLW', 'CAM', 'NUE', 'HD', 'CIEIQ', 'THC', 'WSM', 'MCRS', 'CMI', 'ISRG', 'EAT', 'STLD', 'PNRA', 'DUK', 'AEO', 'KMX', 'TEL', 'DOW', 'PEG', 'TRQ', 'CAB', 'EBAY', 'JBL', 'VIAC', 'RHI', 'FOSL', 'PKG', 'PPG', 'LNC', 'TEX', 'HMY', 'EMN', 'SGEN', 'FISV', 'M', 'IMG.TO', 'CYH', 'UAL', 'SYK', 'ZION', 'NDAQ', 'KEX', 'CFN', 'KSU', 'LOW', 'BTU', 'LH', 'DNKN', 'PCL', 'MTD', 'O', 'EQIX', 'SBAC', 'ROK', 'AGI', 'TRW', 'T', 'TROW', 'MMC', 'AN', 'ABT', 'FTI', 'ALL', 'AME', 'HIG', 'LUMN', 'GPS', 'AMG', 'AKAM', 'SNI', 'WAB', 'GIS', 'AMZN', 'AVP', 'BLK', 'TNL', 'ADP', 'HRB', 'CDNS', 'BSX', 'MS', 'XL', 'AEP', 'SBNY', 'PGR', 'BEN', 'OC', 'UHS', 'BHI', 'PAYX', 'MSM', 'ON', 'TSS', 'CLX', 'BDX', 'GRA', 'LBTYA', 'LBTYK', 'NVR', 'QRTEA', 'PAAS.TO', 'SCHW', 'SLB', 'HAL', 'STT', 'IDXX', 'TOC', 'AMP', 'OIS', 'EFX', 'RL', 'SDRLF', 'BMY', 'SRCL', 'ASH', 'MSCI', 'URS', 'CSC', 'ACAS', 'HUN', 'JAH', 'LM', 'BEAV', 'AAP', 'BKS', 'GT', 'LXK', 'SWI', 'CHS', 'FLEX', 'PMCS', 'POT', 'KO', 'AGU', 'SYY', 'EA', 'ORLY', 'SHW', 'TGT', 'JOY', 'TSN', 'PSX', 'BBBY', 'BIIB', 'SPGI', 'URBN', 'VIAB', 'LB', 'MOS', 'WMT', 'SO', 'UNP', 'KSS', 'FLR', 'ETR', 'WDC', 'CCI', 'CMG', 'CTSH', 'PCAR', 'NEE', 'AXP', 'ILMN', 'SE', 'GD', 'ADI', 'HFC', 'ELV', 'ARG', 'MMM', 'HST', 'ROST', 'HUM', 'FMC', 'JCI', 'IHS', 'NLY', 'COST', 'PCG', 'ADM', 'PLD', 'PSA', 'HSY', 'AMT', 'MDLZ', 'RCL', 'CF', 'SPG', 'TAP', 'INGR', 'GRPN', 'PM', 'AMGN', 'LHX', 'LKQ', 'TRMB', 'MAN', 'CTAS', 'MSGN', 'CNP', 'BF-B', 'LLL', 'CSX', 'RSG', 'VAL', 'BG', 'RE', 'CSL', 'TECH', 'GWR', 'IFF', 'AOL', 'STI', 'CRL', 'FICO', 'COLM', 'FDS', 'JKHY', 'HBI', 'NUAN', 'FITB', 'ALK', 'CIT', 'FNF', 'MDP', 'DLX', 'RF', 'WLY', 'DNY', 'APH', 'LEG', 'SNA', 'NEU', 'CYT', 'RPM', 'BAC', 'WLK', 'NWL', 'CE', 'EIX', 'PCH', 'WCN', 'LYB', 'VRSK', 'CLB', 'CBT', 'MLM', 'SPNX', 'BMS', 'OII', 'TW', 'SM', 'FCS', 'FLT', 'LII', 'SWKS', 'DNB', 'PBI', 'TUP', 'OAS', 'AVY', 'CXW', 'ISIL', 'CY', 'AVX', 'BRCD', 'EWZ', 'DIS', 'TOL', 'SBUX', 'MCD', 'DISH', 'MRK', 'UTHR', 'YUM', 'DRI', 'DHI', 'TXT', 'NRG', 'STJ', 'D', 'FDX', 'TFCFA', 'FL', 'KDP', 'STZ', 'RCI-B.TO', 'FE', 'VNO', 'BWA', 'RMD', 'UPS', 'LVLT', 'WBA', 'PVH', 'DISCA', 'HOLX', 'EXC', 'EW', 'TEVA', 'DE', 'CPB', 'BXP', 'DAL', 'MNST', 'MSGS', 'SPLK', 'MD', 'AMCX', 'MJN', 'PFG', 'REGN', 'IEMG', 'EWY', 'ENDP', 'CLF', 'GME', 'IPG', 'CPRI', 'CVS', 'LULU', 'LEN', 'X', 'HYG', 'TJX', 'JCPNQ', 'PX', 'RIG', 'NFX', 'COF', 'XEC', 'SWK', 'BTO.TO', 'JLL', 'CA', 'TAHO', 'F', 'CFR', 'SJM', 'SBH', 'CBRE', 'SBSW', 'AIZ', 'HBAN', 'SCG', 'USB', 'SEE', 'BPYU', 'VMC', 'TFC', 'MCO', 'FIS', 'LEA', 'CMA', 'L', 'PBCT', 'RGA', 'APD', 'CCK', 'CME', 'ALV', 'MKC', 'JPM', 'HRL', 'IVZ', 'DFS', 'OGE', 'ROP', 'TPR', 'LAMR', 'NNN', 'PWR', 'GLD', 'TLT', 'EMB', 'VEA', 'EFA', 'IEFA', 'IAU', 'TIP', 'EWT', 'KMB', 'PG', 'PPL', 'CMCSA', 'RY.TO', 'BNS.TO', 'CAT', 'CNR.TO', 'BMO.TO', 'BKAA.SG', 'CCEP.AS', 'WFC', 'MFC.TO', 'XRAY', 'CM.TO', 'BCE.TO', 'NTR.TO', 'SLF.TO', 'CP.TO', 'RS', 'V', 'T.TO', 'MG.TO', 'WPM.TO', 'J', 'CAKE', 'COO', 'GIB', 'C', 'NYCB', 'RJF', 'UNM', 'MPC', 'WAT', 'IT', 'FTNT', 'CVLT', 'SNPS', 'QSR', 'ECL', 'FTS.TO', 'ARE', 'BKI', 'AGCO', 'JEF', 'GPN', 'PPL.TO', 'IRM', 'CACI', 'KEY', 'WTW', 'PKI', 'ATR', 'OI', 'CHH', 'BALL', 'PNC', 'LPT', 'GL', 'FRT', 'NWSA', 'MORN', 'MTB', 'WRK', 'ALGN', 'HSIC', 'HRC', 'BRKR', 'PDCO', 'EXR', 'LPNT', 'BIO', 'GIL.TO', 'SCI', 'TSCO', 'ALLE', 'TPH', 'AJG', 'UDR', 'IEX', 'BB.TO', 'WCG', 'FLS', 'RRX', 'OSK', 'DCI', 'CFX', 'TTC', 'WPG', 'CR', 'GGG', 'VMI', 'SJR-B.TO', 'STWD', 'SITC', 'SVC', 'AYI', 'CPT', 'GATX', 'DLR', 'ACC', 'VRE', 'REG', 'LECO', 'SLG', 'DEI', 'WRI', 'HUBB', 'KIM', 'OFC', 'NDSN', 'ESS', 'TWO', 'HR', 'DHC', 'ELME', 'KRC', 'EWBC', 'BHC', 'AEE', 'LNT', 'WTRG', 'AWK', 'GXP', 'WEC', 'DTE', 'AES', 'MDU', 'PNW', 'ES', 'XEL', 'ATO', 'VVC', 'CMS', 'UGI', 'IDA', 'KL', 'PNM', 'ALB', 'FLO', 'SMG', 'CHD', 'TSLA', 'CIEN', 'FLIR', 'NATI', 'KN', 'VSH', 'EXPD', 'NOW', 'ROL', 'ATGE', 'BCO', 'CPRT', 'ERIE', 'CLGX', 'FAF', 'AGO', 'CINF', 'KMPR', 'MCY', 'WRB', 'AFG', 'CNA', 'THG', 'ORI', 'PRA', 'PVG', 'TMUS', 'ST', 'RNR', 'AXS', 'AMTD', 'JWN', 'EWW', 'HOUS', 'BABA', 'VFC', 'GIB-A.TO', 'TRI.TO', 'BIDU', 'JD', 'VRTX', 'NTES', '0A2I.IL', 'OTEX', 'EXPE', 'HOG', 'CVI', 'YUMC', 'TCOM', 'ATHM', 'EDU', '0A2X.IL', 'JBGS', 'NVT', 'WH', 'LOGM', 'INDA', 'TRN', 'NTRS', 'WP', 'NYT', 'QEP', 'MOMO', '0LQ0.IL', 'SINA', 'PTC', 'JOBS', 'DPZ', 'LNG', 'YY', 'GDS', 'JACK', 'CL', 'MCHI', 'FXI', 'TRP.TO', '0A2S.IL', 'APTV', 'ODFL', 'GPC', 'UBER', 'DG', 'DD', 'HCA', 'KHC', 'ZTO', 'AOS', 'UHAL', 'GNTX', 'KNX', 'EQR', 'AVB', 'INFO', 'UAA', 'AXTA', '0XWG.IL', 'SRE', 'GM', 'DLTR', 'WDAY', '0A2Z.IL', 'CRI', 'MKL', 'WUBA', 'PEAK', 'POOL', 'ZBH', 'ACGL', 'CDW', 'TPX', 'THO', 'OMC', 'WB', 'LYFT', 'HLT', 'LW', 'FAST', 'SNAP', 'DOX', 'AGR', 'LDOS', 'KBH', 'ANET', 'EVRG', 'MDC', 'R', 'SSW', 'VC', 'NSC', 'NI', 'HCM', 'ADSK', 'FTV', 'BZUN', 'PPC', 'NOAH', 'LANC', 'CW', 'HTZGQ', 'OVV.TO', 'USFD', 'CTB', 'FANG', 'ADNT', 'ZNGA', 'SSRM.TO', 'COTY', 'ODP', 'CCO', 'BEKE', 'VEEV', 'TT', 'LU', 'BILI', '49BA.SG', 'XPEV', 'SAM', 'AON', 'DAR', 'CHGG', 'BK', 'WST', 'CARR', 'DXCM', 'ZLAB', 'ARMK', 'BFAM', 'CASY', 'STE', 'GH', 'ABMD', 'BYND', 'TXRH', 'FRC', 'TFX', 'MASI', 'FRPT', 'SIVB', 'OLLI', 'HELE', 'LOPE', 'MKTX', 'PFGC', 'PEN', 'HLF', 'CFG', 'LI', 'AMED', 'EQH', 'FIZZ', 'BRO', 'CVNA', 'LPLA', 'SEIC', 'TREX', 'CHE', 'FHN', 'DY8A.F', 'CBSH', 'VOYA', 'ARCC', 'WEED.TO', 'QDEL', 'TFSL', 'FOXA', 'HUYA', 'SNV', 'INOV', 'VRM', 'TDOC', 'BOKF', 'BPOP', 'VLY', 'SHOP', 'OZK', 'SIRI', 'STN.TO', 'PACW', 'CRON.TO', 'KMI', 'BOH', 'WFG.TO', '217A.SG', 'ASB', 'SUI', 'PANW', 'FHI', 'WAFD', 'INVH', 'ELS', 'MAA', 'BERY', 'ELD.TO', 'TFII.TO', 'CAE.TO', 'CFFN', 'INSP', 'WPC', 'RNG', 'BKR', 'AYX', 'VTRS', 'SHAK', 'CBOE', 'OMCL', 'BBY', 'ALSN', 'DOO.TO', 'RBA', 'HII', 'EQX.TO', 'PAYC', 'CSGP', 'HAIN', 'CACC', 'VER', 'OHI', 'CRWD', 'CIGI.TO', 'CDAY', 'PYPL', 'SRPT', 'HTA', 'WWE', 'DECK', 'EHC', 'HHC', 'MX.TO', 'VET.TO', 'SRC', 'FCN', 'MA', 'NKTR', 'NEPT.TO', 'SEB', 'PRMW.TO', 'CELH', 'ERF.TO', 'CIM', 'TA.TO', 'NG.TO', 'BEST', 'LIN', 'MBB', 'ABNB', 'BZ', 'PODD', 'A', 'CTVA', 'DIDI', 'LEGN', 'HPQ', 'KEYS', 'AMD', 'NET', 'ZS', 'ZBRA', 'IBKR', 'ABBV', 'AVGO', 'DOCS', 'AMH', 'HPE', 'NVST', 'NVCR', 'TNDM', 'UI', 'SAFM', 'SWAV', 'SFM', 'XYL', 'PZZA', 'SI', 'GMED', 'DADA', 'SMPL', 'MRNA', 'SPB', 'U', 'TWNK', 'LSI', 'OLED', 'AMN', 'CBRL', 'CGNX', 'LHCG', 'EVH', 'ICUI', 'MMSI', 'PLTR', 'QFIN', 'WDFC', 'AGL', 'ENSG', 'GRMN', 'IART', 'Z', 'IRTC', 'CERT', 'NUS', 'GHC', 'ACHC', 'COUR', 'PINC', 'ACI', 'FSLR', 'EPC', 'COKE', 'CALM', 'CENTA', 'IR', 'TER', 'STAA', 'DT', 'HUBS', 'LNTH', 'MED', 'LEVI', 'RELX', 'PSMT', 'DELL', 'XPO', 'AZN', 'SDGR', 'GKOS', 'THS', 'NARI', 'MPWR', 'NEOG', 'OSH', 'GDRX', 'HAE', 'JJSF', 'IRBT', 'RUN', 'REYN', 'IPAR', 'ARW', 'CD', 'SKIN', 'GSK', 'ATRC', 'NUVA', 'SNN', 'STRA', 'ENTG', 'BR', 'SKX', 'INCY', 'LRN', 'QRVO', 'SNOW', 'ITGR', 'OKE', 'IPGP', 'WOLF', 'NVRO', 'PHR', 'ELF', 'OLPX', 'WMK', 'IQV', 'BSY', 'IMKTA', 'AXNX', 'GEN', 'HCAT', 'MGPI', 'GWRE', 'API', 'LBRDA', 'NXGN', 'OM', 'CWEN', 'MIDD', 'DUOL', 'PNR', 'FIGS', 'KC', 'SEDG', 'TWOU', 'MSA', 'ONEM', 'BRBR', 'USNA', 'CYRX', 'NVTA', 'MODV', 'RH', 'CWT', 'CRVL', 'AVNS', 'QGEN', 'FND', 'SLP', 'REGI', 'TTWO', 'BIG', 'DASH', 'ARES', 'ADUS', 'AMWL', 'AMEH', 'CUBE', 'HSKA', 'CTLT', 'TDG', 'RUTH', 'SILK', 'TTD', 'MLAB', 'USPH', 'LAD', 'FLGT', 'CMC', 'LAZR', 'PRVA', 'CAR', 'BJRI', 'ITRI', 'EPAM', 'CSTM', 'OPRX', 'VIVO', 'CVGW', 'CNC', 'MDB', 'RPRX', 'CNS', 'LYV', 'AHCO', 'SPWR', 'NFLX', 'STOR', 'BNR', 'SPTN', 'CSTL', 'ATRI', 'TIGO', 'ACCD', 'SII.TO', 'CERS', 'LMAT', 'NTUS', 'CSII', 'BLFS', 'NHC', 'HZNP', 'ZI', 'TDY', 'TIGR', 'ANGO', 'AVTR', 'OCFT', 'HEI', 'AA', 'WMG', 'CC', 'MOH', 'TRU', 'KIDS', 'CCRN', 'NRC', 'TYL', 'LUNG', 'SIBN', 'VIRT', 'VRAY', 'WAL', 'ROKU', 'WT', 'HWM', 'PINS', 'MAC', 'CHWY', 'DKS', 'LAC.TO', 'ETSY', 'RYN', 'CLS.TO', 'JNK', 'GDDY', 'ALKS', 'JYNT', 'ZIMV', 'HSC', 'EXAS', 'AGNC', 'BURL', 'AMC', 'CG.TO', 'HAS', 'GLPI', 'MTN', 'BKD', 'BAH', 'CNO', 'CMP', 'HE', 'RGEN', 'POST', 'OCDX', 'BLDR', 'WTS', 'HBM.TO', 'FIVE', 'TCMD', 'ZTS', 'CABO', 'PTON', 'AXON', 'NBIX', 'TXG', 'DBX', 'DLB', 'SR', 'WEX', 'QS', 'TTEC', 'FDP', 'MAT', 'EEFT', 'ALE', 'TSP', 'USM', 'AVA', 'CDXS', 'EXEL', 'ITT', 'PDM', 'NTLA', 'PII', 'BC', 'SQ', 'SLAB', 'NTNX', 'SPR', 'NCR', 'NVAX', 'TDC', 'RHP', 'NKE', 'IONS', 'WEN', 'SXT', 'UVV', 'TWLO', 'SIX', 'DNLI', 'NTRA', 'ACAD', 'SIL.TO', 'ANGI', 'DENN', 'SPCE', 'LGO.TO', 'BLDP.TO', 'SKLZ', 'HWP', 'TIF', 'AXLL', 'CVC', 'TIBX', 'WOOF', 'BGC', 'ADT', 'TCO', 'ATG', 'AVT', 'DDS', 'COL', 'CHTR', 'GNW', 'H', 'TIME', 'UFS', 'GES', 'CBLAQ', 'ATI', 'SON', 'AXE', 'MUSA', 'PAG', 'ULTA', 'AIV', 'VSM', 'REZI', 'MANH', 'ACM', 'HDS', 'CDK', 'NAV', 'FEYE', 'AMKR', 'TGNA', 'KMT', 'WOR', 'VIAV', 'OLN', 'RMBS', 'GEF', 'SCS', 'MLKN', 'WSO', 'CRS', 'SSYS', 'DDD', 'SGFY', 'OTIS', 'VCRA', 'VOD', 'OKTA', 'JBSS', 'EAR', 'PRDO', 'INGN', 'ALNY', 'COUP', 'TMDX', 'OSUR', 'COLD', 'CONE', 'MPW', 'NXPI', 'AER', 'CVA', 'CLH', 'RAMP', 'WBD', 'LBRDK', 'PDCE', 'LPX', 'SLM', 'DXC', 'NXST', 'STX', 'BBWI', 'EVR', 'CROX', 'KOS', 'ZM', 'SANM', 'ATUS', 'LCID', 'SHOO', 'RCM', 'TROX', 'EXP', 'RDFN', 'GPI', 'ENOV', 'MATX', 'WWW', 'BLMN', 'GTN', 'MTH', 'ABG', 'MLI', 'PRGS', 'SPOT', 'BNTX', 'RIVN', 'TRGP', 'DOCU', 'CUTR', 'NSP', 'UFPI', 'DNA', 'COIN', 'IAC', 'LSTR', 'HOOD', 'VST', 'MRVL', 'VICI', 'PEGA', 'MRTX', 'AUR', 'LFST', 'SABR', 'ANF', 'MYL', 'RDC', 'DISCK', 'KRFT', 'CVD', 'FSL', 'OCR', 'WDR', 'AAL', 'PRE', 'EGN', 'QLGC', 'TECD', 'TDS', 'PLCM', 'GHL', 'EV', 'JHG', 'HXL', 'CLC', 'DOFSQ', 'GNCIQ', 'CSRA', 'LVGO', 'PLAN', 'COHR', 'PCTY', 'COMM', 'W', 'JAZZ', 'AUPH', 'ESTC', 'GOOS.TO', 'NXE.TO', 'DML.TO', 'BJ', 'TSM', 'COOP', 'ADC', 'WERN', 'AR', '0FUT.IL', 'LITE', 'RUSHA', 'SEAS', 'MTG', 'GSKN.MX', 'NAVI', 'BX', 'GPK', 'EPR', 'MELI', 'HMN', 'CHDN', 'SMTC', 'DK', 'LSXMA', 'FRSH', 'CLVT', 'OPK', 'FRX', 'LO', 'BEAM', 'WLTW', 'TGI', 'ROC', 'TWC', 'TWTC', 'NBR', 'CVG', 'TWX', 'WW', 'NCLH', 'BWXT', 'JBLU', 'MIC', 'BYD', 'PENN', 'SAVE', 'STAY', 'TIVO', 'KELYA', 'DDOG', 'PARA', 'GNRC', 'ENPH', 'ZG', 'ARNA', 'TLRY', 'OGI.TO']

# %%
institution = 'Bridgewater Associates, LP'
y = '2013'
q = 'Q4'
df = pd.read_csv(f'./people/{institution}/{institution} {q} {y} 13F Top Portfolio Holdings.csv')
df.head()
# Out:
#    Sym                   Issuer Name                Cl      CUSIP  \
# 0  VWO  VANGUARD INTL EQUITY INDEX F  FTSE EMR MKT ETF  922042858
# 1  SPY           SPDR S&P 500 ETF TR           TR UNIT  78462F103
# 2  EEM                       ISHARES  MSCI EMG MKT ETF  464287234
# 3  LQD                       ISHARES  IBOXX INV CP ETF  464287242
# 4  IVV                       ISHARES   CORE S&P500 ETF  464287200
#
#   Value ($000)     %       Shares  Principal  Option Type
# 0    4,200,302   34%  102,097,760        NaN          NaN
# 1    3,543,610   28%   19,186,800        NaN          NaN
# 2    3,235,870   26%   77,422,430        NaN          NaN
# 3       43,089  0.3%      377,355        NaN          NaN
# 4       32,489  0.3%      175,000        NaN          NaN

# %%
df_merged = pd.DataFrame(columns=['Sym', 'Amount'])

# %%
institution = 'Berkshire Hathaway Inc'
quarters = ['Q1','Q2','Q3','Q4']
years = [str(y) for y in range(2013,2023)]
for y in years:
    for q in quarters:
        try:
            df = pd.read_csv(f'./people/{institution}/{institution} {q} {y} 13F Top Portfolio Holdings.csv')
            for i in range(len(df)):
                df['Value ($000)'][i]=df['Value ($000)'].values[i].replace(',','')
            df['Value ($000)'] = df['Value ($000)'].astype(float)
            df = df.drop(['Cl','CUSIP','%','Principal','Option Type','Issuer Name','Shares'], axis=1)
        
            quarter_dict = {'Q1':'03-31','Q2':'06-30','Q3':'09-30','Q4':'12-31'}
            day = y+'-'+quarter_dict[q]
            dday = pd.to_datetime(day)
            # NumShares = []
            for i in range(len(df)):
                try:
                    ticker = df['Sym'][i]
                    prices = pdr.get_data_yahoo(ticker,start=day - timedelta(2), end = dday + timedelta(3))['Close']
                    try:
                        price = prices.loc[y+'-'+quarter_dict[q]]
                    except:
                        price = prices.iloc[0]
                    df['Value ($000)'][i] = round(df['Value ($000)'][i]/price,1)
                    #NumShares.append(np.round(amt,1))
                    
                except:
                    print('shat')
                    pass
            df.rename(columns={'Value ($000)':'Amount (000)'}, inplace=True)
            
            for i in range(len(df)):
                if df['Sym'][i] not in stocks_use:
                    df.drop(i, axis=0,inplace=True)
            df.reset_index(inplace=True)
            del df['index']
            
            cnt = len(df)
            for s in stocks_use:
                if s not in list(df['Sym']):
                    df.loc[cnt] = [s, 0]
                    cnt += 1
            if len(df) != 90:
                print(f'Error for {y} {q}')
                break;
            
            quarter_dict2 = {'Q1':'03-01','Q2':'06-01','Q3':'09-01','Q4':'12-01'}
            df['date'] = pd.to_datetime(f'{y}-{quarter_dict2[q]}')
            df = df.set_index('date')
            
            df_merged = pd.concat([df_merged,df],axis=0)
            print(f'Merged {y} {q}!')
        except:
            print(f'Error with Loading Data {y} {q}..')
            pass
# Out:
# Error with Loading Data 2013 Q1..
# Error with Loading Data 2013 Q2..
# Error with Loading Data 2013 Q3..
# /var/folders/h2/xtv6rzm1081cpt_clcdbqmt00000gn/T/ipykernel_8419/2645054532.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value ($000)'][i]=df['Value ($000)'].values[i].replace(',','')
# [*********************100%***********************]  1 of 1 completed
# /var/folders/h2/xtv6rzm1081cpt_clcdbqmt00000gn/T/ipykernel_8419/2645054532.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value ($000)'][i] = round(df['Value ($000)'][i]/price,1)
# ...

# %%
sum(df_merged['Amount (000)'].isna())
# Out:
# 0

# %%
del df_merged['Amount']

# %%
df_merged.to_csv('NumShares_Buffet.csv')

# %%
df_merged.groupby('Sym').mean()
# Out:
#       Amount (000)
# Sym
# AAL   7.589911e+04
# AAPL  7.489535e+05
# ABBV  2.989600e+03
# ALLY  1.915817e+03
# AMZN  4.413669e+03
# ...            ...
# VRSN  3.984342e+04
# VZ    2.785644e+04
# WFC   1.055213e+06
# WMT   2.037333e+04
# XOM   4.569956e+03
#
# [90 rows x 1 columns]

# %%
df_merged
# Out:
#               Sym  Amount (000)
# 2013-12-01    WFC      463458.1
# 2013-12-01     KO      400000.0
# 2013-12-01    AXP      151610.7
# 2013-12-01    IBM       71255.6
# 2013-12-01     PG       52793.1
# ...           ...           ...
# 2022-09-01  FWONA           0.0
# 2022-09-01    OGN           0.0
# 2022-09-01      T           0.0
# 2022-09-01   ORCL           0.0
# 2022-09-01    PFE           0.0
#
# [3240 rows x 2 columns]
